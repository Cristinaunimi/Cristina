# %% [markdown]
# # <font color='yellow'> ***TORTA ALLO YOGURT***</font>

# %% [markdown]
# ![torta-allo-yogurt.jpg](attachment:a49e4160-5f2f-4400-850a-7d981dd62d72.jpg)

# %% [markdown]
# # **Ingredienti (per uno stampo da 24 cm)**

# %%
n=24

# %%
Yogurt=320
print ("Yogurt:", Yogurt)
Burro=150
print ("Burro:", Burro)
Farina=250
print ("Farina:", Farina)
Limone=1
print ("Limone:", Limone)
Lievito=16
print ("Lievito:", Lievito)
Uova=4
print ("Uova:", Uova)
Zucchero=200
print ("Zucchero:", Zucchero)
Maizena=80
print ("Maizena:", Maizena)
Sale=1
print ("Sale:", Sale)
# Out:
# Yogurt: 320
# Burro: 150
# Farina: 250
# Limone: 1
# Lievito: 16
# Uova: 4
# Zucchero: 200
# Maizena: 80
# Sale: 1
